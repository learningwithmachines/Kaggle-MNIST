# %%
import numpy as np
from numba import jit
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
@jit
def cyclic_lr(basecycles=3, epochs):
    
    epochs = np.arange(1, epochs+1)
    modulus = np.int(epochs/basecycles)

# %%
plt.plot(cyclic_lr(50))
