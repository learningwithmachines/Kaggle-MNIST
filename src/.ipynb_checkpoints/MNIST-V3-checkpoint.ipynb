# %%
from IPython.core.interactiveshell import InteractiveShell
import os
import sys
import time
from functools import partial
import pickle
import multiprocessing
import pixiedust as pxdb
import PIL
from matplotlib import pyplot as plt
import seaborn as sns
from collections import OrderedDict as ODict
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# PYTORCH
import torch as tc
import torchvision as tcvis
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torch import nn, optim
from torch.nn import functional as fu
# TORCH HELPERS
from ignite.engine import Engine, Events, create_supervised_trainer, create_supervised_evaluator
from ignite.metrics import Accuracy, Loss
import hiddenlayer as hl
from torchsummary import summary
from tqdm import tqdm_notebook as tqdm

InteractiveShell.ast_node_interactivity = 'all'

# %pixie_debugger
# %matplotlib inline

# %config InlineBackend.figure_format = 'retina'
sns.set(style='white', context='notebook', palette='tab10')
# %config IPCompleter.greedy = True
# %config IPCompleter.use_jedi = True


basepath = '/home/alk/Documents/Git/Kaggles/MNIST'
try:
    os.chdir(basepath)
    print(os.getcwd())
except NotADirectoryError:
    pass
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.15</span>
#         </div>
# /home/alk/Documents/Git/Kaggles/MNIST

# %%
rota

# %%
# run only when needed

datadir = os.getcwd() + '/data'
filenames = ['train.csv', 'test.csv']
datadict = ODict()
for files in filenames:
    try:
        with open(datadir + '/' + files, mode='r') as csvfile:
            datadict[files] = np.loadtxt(csvfile, delimiter=",", skiprows=1)
            csvfile.close()
        print('found file: {}'.format(files))
    except FileNotFoundError:
        print('skipping file ./{}'.format(files))

print(datadict.keys(), filenames)
# Out:
# found file: train.csv
# found file: test.csv
# odict_keys(['train.csv', 'test.csv']) ['train.csv', 'test.csv']

# %%
traindata = datadict[filenames[0]]
testdata = datadict[filenames[-1]]

trainlabels = traindata[:, 0].reshape(-1, 1)
traindata = traindata[:, 1:].reshape(-1, 28, 28)
testdata = testdata.reshape(-1, 28, 28)
print(traindata.shape, trainlabels.shape, testdata.shape)
# Out:
# (42000, 28, 28) (42000, 1) (28000, 28, 28)

# %%
x_train, x_valid, y_train, y_valid = train_test_split(traindata, trainlabels, 
                                                      test_size=0.2)

# %%
fig, ax = plt.subplots(1, 2, sharex=True, squeeze=True)
ax[0].imshow(x_train[-1, :, :], cmap='gray')
ax[1].imshow(x_valid[0, :, :], cmap='gray')

# %%
class NpDataset(Dataset):

    def __init__(self, x=x_train, y=y_train,
                 transforms=None):
        super().__init__()

        self.x = x
        self.y = y
        self.transform = transforms
        
    def __len__(self):

        return self.x.shape[0]

    def __getitem__(self, index):

        if self.y is not None:
            image, label = self.x[index], self.y[index]
            label = tc.from_numpy(label).type(tc.LongTensor)
        else:
            image, label = self.x[index], None
        
        # HxWxC, UINT8
        image = image.astype(np.uint8).reshape(28, 28, 1)
        # image = tc.from_numpy(image).type(tc.FloatTensor)

        if self.transform is not None:
            image = self.transform(image)

        return image, label

# test
test_set = NpDataset()
print(f'target: {test_set.__getitem__(0)[1]}')
plt.imshow(test_set.__getitem__(0)[0].reshape(28, 28), cmap='gray')
# Out:
# target: tensor([4])

# %%
MNIST_train_transform = transforms.Compose([transforms.ToPILImage(),
                                            transforms.RandomAffine(30, (0.15,0.15),
                                                                    (0.75,1.25), 30,
                                                                    PIL.Image.BICUBIC,0),
                                            transforms.ToTensor(),
                                            transforms.Normalize((0.1307,),
                                                                 (0.3081,))])

MNIST_test_transform = transforms.Compose([transforms.ToTensor(),
                                           transforms.Normalize((0.1307,),
                                                                (0.3081,))])

# test
test_set = NpDataset(transforms=MNIST_train_transform)

fig, axes = plt.subplots(5, 5, sharex=True, sharey=True)
_plots = None

for axs in axes:
    for ax in axs:
        data = test_set.__getitem__(np.random.randint(0, x_train.shape[0]))
        _plots = ax.imshow(data[0].reshape(28, 28), cmap='gray');
        _plots = ax.set_ylabel(str(data[1].numpy()))
        
_plots = plt.yticks([], [])
_plots = plt.xticks([], [])
_plots = plt.axis('off')
plt.show()

# %%
def my_collate(batch):
    
    data = tc.stack([item[0] for item in batch])
    target = tc.stack([item[1] for item in batch])
    
    return [data, target.view(-1)]

NN_trainloader = DataLoader(NpDataset(transforms=MNIST_train_transform),
                            batch_size=105,
                            shuffle=True,
                            collate_fn=my_collate,
                            num_workers=8,
                            pin_memory=True)

NN_testloader = DataLoader(NpDataset(x=x_valid, y=y_valid,
                                     transforms=MNIST_test_transform),
                           batch_size=105,
                           shuffle=True,
                           collate_fn=my_collate,
                           num_workers=8,
                           pin_memory=True)

# test
img, lbl = next(iter(NN_trainloader))
print(img.shape, lbl.shape)
# Out:
# torch.Size([210, 1, 28, 28]) torch.Size([210])

# %%
class MNIST_CNN(nn.Module):
    
    def __init__(self,
                 dropout_fcp=0.0):
        super(MNIST_CNN, self).__init__()
        
        self.dropout_p = dropout_fcp
        
        self.conv1 = nn.Conv2d(1, 25, 5, 1) #24
        self.conv2 = nn.Conv2d(25, 50, 5, 1) #20
        
        self.conv3 = nn.Conv2d(1, 50, 7, 1)
        self.conv4 = nn.Conv2d(50, 100, 7, 1)
        
        self.fc1a = nn.Linear(4*4*50, 400)
        self.fc1b = nn.Linear(4*4*100, 400)
        
        self.fcf1 = nn.Linear(800,100)
        self.fcf2 = nn.Linear(100,10)
        
    def forward(self, x):
        
        x1 = fu.relu(self.conv1(x))
        x1 = fu.max_pool2d(x1, 2, 2)
        x1 = fu.relu(self.conv2(x1))
        x1 = fu.max_pool2d(x1, 2, 2)
        x1 = x1.view(-1, 4*4*50)
        x1 = fu.relu(self.fc1a(x1))
        x1 = fu.dropout(x1, p=self.dropout_p, 
                        training=self.training)
        
        x2 = fu.relu(self.conv3(x))
        x2 = fu.relu(self.conv4(x2))
        x2 = fu.max_pool2d(x2, 4, 4)
        x2 = x2.view(-1, 4*4*100)
        x2 = fu.relu(self.fc1b(x2))
        x2 = fu.dropout(x2, p=self.dropout_p, 
                        training=self.training)
        
        x = tc.cat((x1, x2), dim=1)
        
        x = fu.relu(self.fcf1(x))
        x = fu.dropout(x, p=self.dropout_p,
                       training=self.training)
        
        x = self.fcf2(x)
        x = fu.log_softmax(x, dim=1)
        
        return x
        
# test

test_cnn = MNIST_CNN().cuda()
print(summary(test_cnn.cuda(), (1,28,28), device='cuda'))
hl.build_graph(model=test_cnn.cuda(), args=tc.randn(1,1,28,28).cuda())
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 25, 24, 24]             650
#             Conv2d-2             [-1, 50, 8, 8]          31,300
#             Linear-3                  [-1, 400]         320,400
#             Conv2d-4           [-1, 50, 22, 22]           2,500
#             Conv2d-5          [-1, 100, 16, 16]         245,100
#             Linear-6                  [-1, 400]         640,400
#             Linear-7                  [-1, 100]          80,100
#             Linear-8                   [-1, 10]           1,010
# ================================================================
# Total params: 1,321,460
# Trainable params: 1,321,460
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.52
# Params size (MB): 5.04
# Estimated Total Size (MB): 5.57
# ----------------------------------------------------------------
# None

# %%
class NN_Trainer():

    def __init__(self, model, 
                 trainloader, testloader,
                 optimizer, loss_fn, wcuda=True):
        
        self.model = model

        self.trainloader = trainloader
        self.testloader = testloader

        self.lossfn = loss_fn
        self.optimizer = optimizer
        self.metrics = {'accuracy':Accuracy(),
                        'loss':Loss(self.lossfn)}
        self.trn_records = {k:[] for k in self.metrics.keys()}
        self.val_records = {k:[] for k in self.metrics.keys()}
        self.bwise_losses = []
        
        if wcuda:
            self.wcuda, self.device = True, 'cuda'
        else:
            self.wcuda, self.device = False, 'cpu'
        
        self.run = self.__call__
    
    def __call__(self, max_epochs, log_interval):
        
        if self.wcuda:
            tc.backends.cudnn.enabled = True
            tc.cuda.empty_cache()
            
        desc = "ITERATION - loss: {:.6f}"
        pbar = tqdm(initial=0, leave=False, total=len(self.trainloader),
                    desc=desc.format(0))
        
        trainer = create_supervised_trainer(self.model,
                                            self.optimizer,
                                            self.lossfn,
                                            device=self.device)

        evaluator = create_supervised_evaluator(self.model,
                                                self.metrics,
                                                device=self.device)
        
        @trainer.on(Events.ITERATION_COMPLETED)
        def log_training_losses(engine):
            
            iter = (engine.state.iteration - 1) % len(self.trainloader) + 1
            
            if iter % log_interval == 0:
                pbar.desc = desc.format(engine.state.output)
                pbar.update(log_interval)
            
            records = engine.state.output 
            self.bwise_losses.append(records)

        @trainer.on(Events.EPOCH_COMPLETED)
        def log_training_results(engine):
            
            pbar.refresh()
            evaluator.run(self.trainloader)
            metrics = evaluator.state.metrics
            avg_accuracy = metrics['accuracy']
            avg_nll = metrics['loss']
            
            tqdm_str = "Training Results - Epoch: {}  \
                        Avg accuracy: {:.6f} Avg loss: {:.6f}"
            pbar.write(tqdm_str.format(engine.state.epoch,
                                       avg_accuracy, avg_nll))
            
            for k in self.metrics.keys():
                self.trn_records[k].append(metrics[k]) 

        @trainer.on(Events.EPOCH_COMPLETED)
        def log_validation_results(engine):
            evaluator.run(self.testloader)
            metrics = evaluator.state.metrics
            avg_accuracy = metrics['accuracy']
            avg_nll = metrics['loss']
            
            tqdm_str = "Validation Results - Epoch: {}  \
                        Avg accuracy: {:.6f} Avg loss: {:.6f}"
            pbar.write(tqdm_str.format(engine.state.epoch,
                                       avg_accuracy, avg_nll))
            
            pbar.n = pbar.last_print_n = 0
            
            for k in self.metrics.keys():
                self.val_records[k].append(metrics[k]) 
        
        self.max_epochs = max_epochs
        trainer.run(self.trainloader, max_epochs)
        pbar.close()
        
    def plot(self, prefix='Base'):
        
        fig = plt.figure(figsize=(12,6))
        ax = plt.subplot(111)
        ax2 = ax.twinx().twiny()
        plt.rc('grid', linestyle="--", color='gray')
        plt.minorticks_on()
        
        plots = [self.trn_records['accuracy'],
                 self.trn_records['loss'],
                 self.val_records['accuracy'],
                 self.val_records['loss']]
        
        labels = ['Training Accuracy',
                  'Training Loss',
                  'Validation Accuracy',
                  'Validation Loss']
        
        colors = ['xkcd:lime', 'xkcd:green', 'xkcd:red', 'xkcd:cerise']
        linestyles = ['-', '--', '-', '--']
        markers = ['o', '+', 'x', '*']


        for series, lab, col, ls, mrk in zip(plots, labels, colors, linestyles, markers):
            ax.plot(series, marker=mrk, linewidth=1, label=lab, color=col, linestyle=ls)
            ax.set_xlabel('Epochs')

        ax2.plot(self.bwise_losses, label='Batchwise Losses', alpha=0.5,
                    color='blue', linestyle='--', linewidth=1)
        ax2.set_xlabel('Batches', color='blue')
        ax2.xaxis.set_ticks_position('bottom')
        ax2.xaxis.set_label_position('bottom')
        ax2.spines['bottom'].set_position(('axes', -0.20))
        ax2.spines['bottom'].set_color('blue')
        ax2.spines['right'].set_color('blue')
        ax2.yaxis.tick_right()
        ax2.yaxis.set_label_position("right")
        ax2.tick_params(axis='y', colors='blue')

        ax.legend(loc='center left', frameon=True, bbox_to_anchor=(1.05, 0.5),
                      ncol=1, fancybox=True)
        ax2.legend(loc='center left', frameon=True, bbox_to_anchor=(1.05, 0.75),
                      ncol=1, fancybox=True)
        ax.grid(which='major', color='black', linestyle='--')
        ax.grid(which='minor', color='gray', linestyle=':')
        plt.title(label=f'Model: {prefix}', loc='center')
  
        plt.show()

# %%
ModelMNIST = MNIST_CNN(dropout_fcp=0.25).cuda()
optimizer = optim.Adam(ModelMNIST.parameters(), lr=0.0001)
loss_fn = fu.nll_loss

TrainMNIST = NN_Trainer(ModelMNIST, NN_trainloader, 
                        NN_testloader, optimizer, loss_fn)

TrainMNIST(150, log_interval=1)
TrainMNIST.plot('MNIST_CNN')
# Out:
# HBox(children=(IntProgress(value=0, description='ITERATION - loss: 0.00', max=160, style=ProgressStyle(descrip…
# Training Results - Epoch: 1                          Avg accuracy: 0.69 Avg loss: 1.00
# Validation Results - Epoch: 1                          Avg accuracy: 0.93 Avg loss: 0.38
# Training Results - Epoch: 2                          Avg accuracy: 0.83 Avg loss: 0.58
# Validation Results - Epoch: 2                          Avg accuracy: 0.95 Avg loss: 0.20
# Training Results - Epoch: 3                          Avg accuracy: 0.87 Avg loss: 0.44
# Validation Results - Epoch: 3                          Avg accuracy: 0.96 Avg loss: 0.14
# Training Results - Epoch: 4                          Avg accuracy: 0.90 Avg loss: 0.34
# Validation Results - Epoch: 4                          Avg accuracy: 0.97 Avg loss: 0.12
# Training Results - Epoch: 5                          Avg accuracy: 0.91 Avg loss: 0.30
# Validation Results - Epoch: 5                          Avg accuracy: 0.97 Avg loss: 0.10
# Training Results - Epoch: 6                          Avg accuracy: 0.93 Avg loss: 0.24
# Validation Results - Epoch: 6                          Avg accuracy: 0.98 Avg loss: 0.08
# Training Results - Epoch: 7                          Avg accuracy: 0.93 Avg loss: 0.22
# Validation Results - Epoch: 7                          Avg accuracy: 0.98 Avg loss: 0.08
# Training Results - Epoch: 8                          Avg accuracy: 0.94 Avg loss: 0.20
# Validation Results - Epoch: 8                          Avg accuracy: 0.98 Avg loss: 0.07
# Training Results - Epoch: 9                          Avg accuracy: 0.95 Avg loss: 0.18
# Validation Results - Epoch: 9                          Avg accuracy: 0.98 Avg loss: 0.06
# Training Results - Epoch: 10                          Avg accuracy: 0.95 Avg loss: 0.16
# Validation Results - Epoch: 10                          Avg accuracy: 0.98 Avg loss: 0.06
# Training Results - Epoch: 11                          Avg accuracy: 0.95 Avg loss: 0.16
# Validation Results - Epoch: 11                          Avg accuracy: 0.98 Avg loss: 0.05
# Training Results - Epoch: 12                          Avg accuracy: 0.95 Avg loss: 0.16
# Validation Results - Epoch: 12                          Avg accuracy: 0.98 Avg loss: 0.05
# Training Results - Epoch: 13                          Avg accuracy: 0.96 Avg loss: 0.14
# Validation Results - Epoch: 13                          Avg accuracy: 0.99 Avg loss: 0.05
# Training Results - Epoch: 14                          Avg accuracy: 0.96 Avg loss: 0.13
# Validation Results - Epoch: 14                          Avg accuracy: 0.98 Avg loss: 0.05
# Training Results - Epoch: 15                          Avg accuracy: 0.96 Avg loss: 0.12
# Validation Results - Epoch: 15                          Avg accuracy: 0.99 Avg loss: 0.04
# Training Results - Epoch: 16                          Avg accuracy: 0.96 Avg loss: 0.12
# Validation Results - Epoch: 16                          Avg accuracy: 0.99 Avg loss: 0.04
# Training Results - Epoch: 17                          Avg accuracy: 0.97 Avg loss: 0.11
# Validation Results - Epoch: 17                          Avg accuracy: 0.99 Avg loss: 0.04
# Training Results - Epoch: 18                          Avg accuracy: 0.97 Avg loss: 0.11
# Validation Results - Epoch: 18                          Avg accuracy: 0.99 Avg loss: 0.04
# Training Results - Epoch: 19                          Avg accuracy: 0.96 Avg loss: 0.11
# Validation Results - Epoch: 19                          Avg accuracy: 0.99 Avg loss: 0.04
# Training Results - Epoch: 20                          Avg accuracy: 0.97 Avg loss: 0.11
# Validation Results - Epoch: 20                          Avg accuracy: 0.99 Avg loss: 0.04
# Training Results - Epoch: 21                          Avg accuracy: 0.97 Avg loss: 0.11
# Validation Results - Epoch: 21                          Avg accuracy: 0.99 Avg loss: 0.04
# Training Results - Epoch: 22                          Avg accuracy: 0.97 Avg loss: 0.09
# Validation Results - Epoch: 22                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 23                          Avg accuracy: 0.97 Avg loss: 0.09
# Validation Results - Epoch: 23                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 24                          Avg accuracy: 0.97 Avg loss: 0.09
# Validation Results - Epoch: 24                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 25                          Avg accuracy: 0.97 Avg loss: 0.08
# Validation Results - Epoch: 25                          Avg accuracy: 0.99 Avg loss: 0.04
# Training Results - Epoch: 26                          Avg accuracy: 0.97 Avg loss: 0.08
# Validation Results - Epoch: 26                          Avg accuracy: 0.99 Avg loss: 0.04
# Training Results - Epoch: 27                          Avg accuracy: 0.97 Avg loss: 0.08
# Validation Results - Epoch: 27                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 28                          Avg accuracy: 0.97 Avg loss: 0.08
# Validation Results - Epoch: 28                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 29                          Avg accuracy: 0.97 Avg loss: 0.08
# Validation Results - Epoch: 29                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 30                          Avg accuracy: 0.98 Avg loss: 0.08
# Validation Results - Epoch: 30                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 31                          Avg accuracy: 0.98 Avg loss: 0.08
# Validation Results - Epoch: 31                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 32                          Avg accuracy: 0.98 Avg loss: 0.08
# Validation Results - Epoch: 32                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 33                          Avg accuracy: 0.98 Avg loss: 0.07
# Validation Results - Epoch: 33                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 34                          Avg accuracy: 0.98 Avg loss: 0.07
# Validation Results - Epoch: 34                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 35                          Avg accuracy: 0.98 Avg loss: 0.08
# Validation Results - Epoch: 35                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 36                          Avg accuracy: 0.98 Avg loss: 0.07
# Validation Results - Epoch: 36                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 37                          Avg accuracy: 0.98 Avg loss: 0.07
# Validation Results - Epoch: 37                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 38                          Avg accuracy: 0.98 Avg loss: 0.07
# Validation Results - Epoch: 38                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 39                          Avg accuracy: 0.98 Avg loss: 0.06
# Validation Results - Epoch: 39                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 40                          Avg accuracy: 0.98 Avg loss: 0.07
# Validation Results - Epoch: 40                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 41                          Avg accuracy: 0.98 Avg loss: 0.06
# Validation Results - Epoch: 41                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 42                          Avg accuracy: 0.98 Avg loss: 0.06
# Validation Results - Epoch: 42                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 43                          Avg accuracy: 0.98 Avg loss: 0.07
# Validation Results - Epoch: 43                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 44                          Avg accuracy: 0.98 Avg loss: 0.06
# Validation Results - Epoch: 44                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 45                          Avg accuracy: 0.98 Avg loss: 0.06
# Validation Results - Epoch: 45                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 46                          Avg accuracy: 0.98 Avg loss: 0.06
# Validation Results - Epoch: 46                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 47                          Avg accuracy: 0.98 Avg loss: 0.06
# Validation Results - Epoch: 47                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 48                          Avg accuracy: 0.98 Avg loss: 0.06
# Validation Results - Epoch: 48                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 49                          Avg accuracy: 0.98 Avg loss: 0.06
# Validation Results - Epoch: 49                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 50                          Avg accuracy: 0.98 Avg loss: 0.06
# Validation Results - Epoch: 50                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 51                          Avg accuracy: 0.98 Avg loss: 0.06
# Validation Results - Epoch: 51                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 52                          Avg accuracy: 0.98 Avg loss: 0.06
# Validation Results - Epoch: 52                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 53                          Avg accuracy: 0.98 Avg loss: 0.05
# Validation Results - Epoch: 53                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 54                          Avg accuracy: 0.98 Avg loss: 0.06
# Validation Results - Epoch: 54                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 55                          Avg accuracy: 0.98 Avg loss: 0.05
# Validation Results - Epoch: 55                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 56                          Avg accuracy: 0.98 Avg loss: 0.06
# Validation Results - Epoch: 56                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 57                          Avg accuracy: 0.98 Avg loss: 0.05
# Validation Results - Epoch: 57                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 58                          Avg accuracy: 0.98 Avg loss: 0.05
# Validation Results - Epoch: 58                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 59                          Avg accuracy: 0.98 Avg loss: 0.05
# Validation Results - Epoch: 59                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 60                          Avg accuracy: 0.98 Avg loss: 0.05
# Validation Results - Epoch: 60                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 61                          Avg accuracy: 0.98 Avg loss: 0.05
# Validation Results - Epoch: 61                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 62                          Avg accuracy: 0.98 Avg loss: 0.05
# Validation Results - Epoch: 62                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 63                          Avg accuracy: 0.98 Avg loss: 0.05
# Validation Results - Epoch: 63                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 64                          Avg accuracy: 0.98 Avg loss: 0.05
# Validation Results - Epoch: 64                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 65                          Avg accuracy: 0.99 Avg loss: 0.05
# Validation Results - Epoch: 65                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 66                          Avg accuracy: 0.98 Avg loss: 0.05
# Validation Results - Epoch: 66                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 67                          Avg accuracy: 0.98 Avg loss: 0.05
# Validation Results - Epoch: 67                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 68                          Avg accuracy: 0.99 Avg loss: 0.05
# Validation Results - Epoch: 68                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 69                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 69                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 70                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 70                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 71                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 71                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 72                          Avg accuracy: 0.99 Avg loss: 0.05
# Validation Results - Epoch: 72                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 73                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 73                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 74                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 74                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 75                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 75                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 76                          Avg accuracy: 0.99 Avg loss: 0.05
# Validation Results - Epoch: 76                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 77                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 77                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 78                          Avg accuracy: 0.99 Avg loss: 0.05
# Validation Results - Epoch: 78                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 79                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 79                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 80                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 80                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 81                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 81                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 82                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 82                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 83                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 83                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 84                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 84                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 85                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 85                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 86                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 86                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 87                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 87                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 88                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 88                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 89                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 89                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 90                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 90                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 91                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 91                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 92                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 92                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 93                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 93                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 94                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 94                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 95                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 95                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 96                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 96                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 97                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 97                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 98                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 98                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 99                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 99                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 100                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 100                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 101                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 101                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 102                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 102                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 103                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 103                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 104                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 104                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 105                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 105                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 106                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 106                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 107                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 107                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 108                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 108                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 109                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 109                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 110                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 110                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 111                          Avg accuracy: 0.99 Avg loss: 0.04
# Validation Results - Epoch: 111                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 112                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 112                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 113                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 113                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 114                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 114                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 115                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 115                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 116                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 116                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 117                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 117                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 118                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 118                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 119                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 119                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 120                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 120                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 121                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 121                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 122                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 122                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 123                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 123                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 124                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 124                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 125                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 125                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 126                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 126                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 127                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 127                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 128                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 128                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 129                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 129                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 130                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 130                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 131                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 131                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 132                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 132                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 133                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 133                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 134                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 134                          Avg accuracy: 0.99 Avg loss: 0.03
# Training Results - Epoch: 135                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 135                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 136                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 136                          Avg accuracy: 1.00 Avg loss: 0.02
# Training Results - Epoch: 137                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 137                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 138                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 138                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 139                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 139                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 140                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 140                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 141                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 141                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 142                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 142                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 143                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 143                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 144                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 144                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 145                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 145                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 146                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 146                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 147                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 147                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 148                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 148                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 149                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 149                          Avg accuracy: 0.99 Avg loss: 0.02
# Training Results - Epoch: 150                          Avg accuracy: 0.99 Avg loss: 0.03
# Validation Results - Epoch: 150                          Avg accuracy: 0.99 Avg loss: 0.02
